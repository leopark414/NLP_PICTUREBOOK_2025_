# %% [markdown]
# <a href="https://colab.research.google.com/github/leopark414/NLP_PICTUREBOOK_2025_/blob/main/_044_045hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
listdata=[42,1,39,27,44,8]
ret1=sorted(listdata)
ret2=sorted(listdata,reverse=True)
print(ret1)
print(ret2)
print(listdata)
# Out:
# [1, 8, 27, 39, 42, 44]
# [44, 42, 39, 27, 8, 1]
# [42, 1, 39, 27, 44, 8]

# %%
tupledata=(1,2,3,4)
ret=sorted(tupledata)
print(ret)
# Out:
# [1, 2, 3, 4]

# %%
strData='qwer'
ret=sorted(strData)
print(ret)
# Out:
# ['e', 'q', 'r', 'w']

# %%
population={'김':123,'이':456,'박':789}
ret=sorted(population)
print(ret)
# Out:
# ['김', '박', '이']

# %%
listdata=[1,2,3,4,5]

# %%
tupledata(1,2,3,4,5)

# %%
strData1='1'
strData2='2'
strData3='3'

# %%
bstr=b'1'
